# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
script_data = pd.read_excel('../data/script_data_2017_2021.xlsx', 
                             sheet_name=['Prescription_Data_2017_2021'])

pop_income = pd.read_csv('../data/TN_pop_201_2019_race_gender.csv')

# %%
scripts = script_data.get('Prescription_Data_2017_2021')

print(scripts)
# Out:
#        Year Geography GeographyType             Indicator  Value ValueType
# 0      2017  Anderson        County   All Benzodiazepines  47803     Count
# 1      2017  Anderson        County            Alprazolam  17502     Count
# 2      2017  Anderson        County            Clonazepam  10869     Count
# 3      2017  Anderson        County              Diazepam   5523     Count
# 4      2017  Anderson        County             Lorazepam   9638     Count
# ...     ...       ...           ...                   ...    ...       ...
# 14710  2021    Wilson        County             Lorazepam     62      Rate
# 14711  2021    Wilson        County  All Opioids for Pain    628      Rate
# 14712  2021    Wilson        County           Hydrocodone    255      Rate
# 14713  2021    Wilson        County             Oxycodone    213      Rate
# 14714  2021    Wilson        County              Tramadol     98      Rate
#
# [14715 rows x 6 columns]

# %%
scripts.shape
# Out:
# (14715, 6)

# %%
county =scripts[scripts["GeographyType"].isin(["County",])]

# %%
county.head(10)
# Out:
#    Year Geography GeographyType             Indicator   Value ValueType
# 0  2017  Anderson        County   All Benzodiazepines   47803     Count
# 1  2017  Anderson        County            Alprazolam   17502     Count
# 2  2017  Anderson        County            Clonazepam   10869     Count
# 3  2017  Anderson        County              Diazepam    5523     Count
# 4  2017  Anderson        County             Lorazepam    9638     Count
# 5  2017  Anderson        County  All Opioids for Pain  100598     Count
# 6  2017  Anderson        County           Hydrocodone   36990     Count
# 7  2017  Anderson        County             Oxycodone   37129     Count
# 8  2017  Anderson        County              Tramadol   12583     Count
# 9  2017  Anderson        County   All Benzodiazepines    8599  Patients

# %%
pop_income.head(10)
# Out:
#    SUMLEV  STATE  COUNTY     STNAME          CTYNAME  YEAR  AGEGRP  TOT_POP  \
# 0      50     47       1  Tennessee  Anderson County     1       0    75129
# 1      50     47       1  Tennessee  Anderson County     1       1     4212
# 2      50     47       1  Tennessee  Anderson County     1       2     4588
# 3      50     47       1  Tennessee  Anderson County     1       3     4617
# 4      50     47       1  Tennessee  Anderson County     1       4     4856
# 5      50     47       1  Tennessee  Anderson County     1       5     3948
# 6      50     47       1  Tennessee  Anderson County     1       6     4064
# 7      50     47       1  Tennessee  Anderson County     1       7     4227
# 8      50     47       1  Tennessee  Anderson County     1       8     4525
# 9      50     47       1  Tennessee  Anderson County     1       9     4890
#
#    TOT_MALE  TOT_FEMALE  ...  HWAC_MALE  HWAC_FEMALE  HBAC_MALE  HBAC_FEMALE  \
# ...

# %%
full_year = []

##loop to check adherence column to determine if early, late, or on time append

for x in pop_income['YEAR']:
    if x ==3:
        full_year.append('2010')
    elif x == 4:
        full_year.append('2011')
    elif x == 5:
        full_year.append('2012')
    elif x == 6:
        full_year.append('2013')
    elif x == 7:
        full_year.append('2014')
    elif x == 8:
        full_year.append('2015')
    elif x == 9:
        full_year.append('2016')
    elif x == 10:
        full_year.append('2017')
    elif x == 11:
        full_year.append('2018')
    elif x == 12:
        full_year.append('2019')
    else:
        full_year.append('NaN')
        
pop_income['full_year']  = full_year

# %%
pop_income.head(10)
# Out:
#    SUMLEV  STATE  COUNTY     STNAME          CTYNAME  YEAR  AGEGRP  TOT_POP  \
# 0      50     47       1  Tennessee  Anderson County     1       0    75129
# 1      50     47       1  Tennessee  Anderson County     1       1     4212
# 2      50     47       1  Tennessee  Anderson County     1       2     4588
# 3      50     47       1  Tennessee  Anderson County     1       3     4617
# 4      50     47       1  Tennessee  Anderson County     1       4     4856
# 5      50     47       1  Tennessee  Anderson County     1       5     3948
# 6      50     47       1  Tennessee  Anderson County     1       6     4064
# 7      50     47       1  Tennessee  Anderson County     1       7     4227
# 8      50     47       1  Tennessee  Anderson County     1       8     4525
# 9      50     47       1  Tennessee  Anderson County     1       9     4890
#
#    TOT_MALE  TOT_FEMALE  ...  HWAC_FEMALE  HBAC_MALE  HBAC_FEMALE  HIAC_MALE  \
# ...

# %%
year_2017 = pop_income[pop_income["full_year"].isin(["2017",])]
year_2017
# Out:
#        SUMLEV  STATE  COUNTY     STNAME          CTYNAME  YEAR  AGEGRP  \
# 171        50     47       1  Tennessee  Anderson County    10       0
# 172        50     47       1  Tennessee  Anderson County    10       1
# 173        50     47       1  Tennessee  Anderson County    10       2
# 174        50     47       1  Tennessee  Anderson County    10       3
# 175        50     47       1  Tennessee  Anderson County    10       4
# ...       ...    ...     ...        ...              ...   ...     ...
# 21617      50     47     189  Tennessee    Wilson County    10      14
# 21618      50     47     189  Tennessee    Wilson County    10      15
# 21619      50     47     189  Tennessee    Wilson County    10      16
# 21620      50     47     189  Tennessee    Wilson County    10      17
# 21621      50     47     189  Tennessee    Wilson County    10      18
#
#        TOT_POP  TOT_MALE  TOT_FEMALE  ...  HWAC_FEMALE  HBAC_MALE  \
# ...

# %%
pop_income1 =pop_income[pop_income["AGEGRP"].isin([0,])]
pop_income1
# Out:
#        SUMLEV  STATE  COUNTY     STNAME          CTYNAME  YEAR  AGEGRP  \
# 0          50     47       1  Tennessee  Anderson County     1       0
# 19         50     47       1  Tennessee  Anderson County     2       0
# 38         50     47       1  Tennessee  Anderson County     3       0
# 57         50     47       1  Tennessee  Anderson County     4       0
# 76         50     47       1  Tennessee  Anderson County     5       0
# ...       ...    ...     ...        ...              ...   ...     ...
# 21565      50     47     189  Tennessee    Wilson County     8       0
# 21584      50     47     189  Tennessee    Wilson County     9       0
# 21603      50     47     189  Tennessee    Wilson County    10       0
# 21622      50     47     189  Tennessee    Wilson County    11       0
# 21641      50     47     189  Tennessee    Wilson County    12       0
#
#        TOT_POP  TOT_MALE  TOT_FEMALE  ...  HWAC_FEMALE  HBAC_MALE  \
# ...

# %%
pop_inc = pop_income1[['full_year','CTYNAME', 'TOT_POP', 'TOT_MALE', 'TOT_FEMALE','AGEGRP' ]]

# %%
pop_inc.head(10)
# Out:
#     full_year          CTYNAME  TOT_POP  TOT_MALE  TOT_FEMALE  AGEGRP
# 0         NaN  Anderson County    75129     36308       38821       0
# 19        NaN  Anderson County    75082     36280       38802       0
# 38       2010  Anderson County    75098     36284       38814       0
# 57       2011  Anderson County    75209     36396       38813       0
# 76       2012  Anderson County    75225     36448       38777       0
# 95       2013  Anderson County    75299     36516       38783       0
# 114      2014  Anderson County    75157     36496       38661       0
# 133      2015  Anderson County    75456     36684       38772       0
# 152      2016  Anderson County    75528     36763       38765       0
# 171      2017  Anderson County    76056     37036       39020       0

# %%
import openpyxl as op

# %%
pop_inc.to_csv('pop_inc.csv')
